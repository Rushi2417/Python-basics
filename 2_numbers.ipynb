# %%
base = 9
height = 7
area =(base*height)/2

area
# Out:
# 31.5

# %%
type(area)
# Out:
# float

# %%
x= 20
y=3

x+y
# Out:
# 23

# %%
x-y
# Out:
# 17

# %%
x/y
# Out:
# 6.666666666666667

# %%
x//y
# Out:
# 6

# %%
x%y
# Out:
# 2

# %%
x, y
# Out:
# (20, 3)

# %%
x**4
# Out:
# 160000

# %%
10+2*3
# Out:
# 16

# %%
(10+2)*3
# Out:
# 36

# %%
foo = 2.3e4

# %%
foo
# Out:
# 23000.0

# %%
1e4
# Out:
# 10000.0

# %%
bar=3.2e-3

# %%
bar
# Out:
# 0.0032

# %%
2e-2
# Out:
# 0.02

# %%
food = 120.54
rent = 400
utilities =200

# %%
total = food+rent+utilities

# %%
total
# Out:
# 720.54

# %%
round(total)
# Out:
# 721

# %%
round(total, 1)
# Out:
# 720.5

# %%
food = "120.34"
rent= "400"

total = food + rent
total
# Out:
# '120.34400'

# %%
food = "120.34"
rent= "400"

total = float(food) + float(rent)
total
# Out:
# 520.34

# %%
import math

x=3
math.sqrt(x)
# Out:
# 1.7320508075688772

# %%
math.floor(8.7)
# Out:
# 8

# %%
math.ceil(8.7)
# Out:
# 9

# %%
math.ceil(8.3)
# Out:
# 9

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
format(5,'b')
# Out:
# '101'

# %%
# Out:
# '1001'
