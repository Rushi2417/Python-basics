# %%
contacts = [('rushi', '88445595'), ('Adi', '782445595'), ('Atharv', '79565231'), ('Arya', '95863475595')]

# %%
for contact in contacts:
    if contact[0] == 'Adi':
        print(contact[1])
# Out:
# 782445595

# %%
type(contacts)
# Out:
# list

# %%
d = {'rushi': 88445595, 'Adi': 782445595, 'Atharv': 79565231, 'Arya': 95863475595}

# %%
type(contacts)
# Out:
# dict

# %%
d['Arya']
# Out:
# 95863475595

# %%
d.get('Satya', 'Not found')
# Out:
# 'Not found'

# %%
d['Adi']=94582113

# %%
d
# Out:
# {'rushi': 88445595, 'Adi': 94582113, 'Atharv': 79565231, 'Arya': 95863475595}

# %%
del d['Arya']
d
# Out:
# {'rushi': 88445595, 'Adi': 94582113, 'Atharv': 79565231}

# %%
'Rushi' in d
# Out:
# False

# %%
contact_dict = {
    'rushi' : {'phone': 1578745, 'address': 'dwswfwefwe'},
    'Adi' : {'phone': 6786866, 'address': 'drfsedfcxzcdv'}
}

# %%
contact_dict['rushi']
# Out:
# {'phone': 1578745, 'address': 'dwswfwefwe'}

# %%
contact_dict['rushi']['phone']
# Out:
# 1578745

# %%
for name in d:
    print(name)
# Out:
# rushi
# Adi
# Atharv

# %%
for name, phone in d.items():
    print(name, phone)
# Out:
# rushi 88445595
# Adi 94582113
# Atharv 79565231

# %%
d.keys()
# Out:
# dict_keys(['rushi', 'Adi', 'Atharv'])

# %%
d.values()
# Out:
# dict_values([88445595, 94582113, 79565231])
