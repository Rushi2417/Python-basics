# %%
can = "coke"

# %%
can
# Out:
# 'coke'

# %%
abc = "coke"

# %%
id(can)
# Out:
# 2683689887600

# %%
id(abc)
# Out:
# 2683689887600

# %%
type(can)
# Out:
# str

# %%
a = 5

# %%
print(a)
# Out:
# 5

# %%
b=a>6

# %%
b
# Out:
# False
