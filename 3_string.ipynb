# %%
first = "Tony"
last = "Stark"

# %%
type(first)
# Out:
# str

# %%
name = first + " " + last
name
# Out:
# 'Tony Stark'

# %%
name = f"{first} {last}"
name
# Out:
# 'Tony Stark'

# %%
age = 28
info = f"{first} {last} is {age} years old"
info
# Out:
# 'Tony Stark is 28 years old'

# %%
name
# Out:
# 'Tony Stark'

# %%
name[0]
# Out:
# 'T'

# %%
name[1]
# Out:
# 'o'

# %%
name[0:4]
# Out:
# 'Tony'

# %%
name[5:]
# Out:
# 'Stark'

# %%
name[-1]
# Out:
# 'k'

# %%
name[-2]
# Out:
# 'r'

# %%
name[12]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 name[12]
#
# IndexError: string index out of range

# %%
len(name)
# Out:
# 10

# %%
name[0]='S'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 name[0]='S'
#
# TypeError: 'str' object does not support item assignment

# %%
food_story = "Welcome to Rushi's House"
s = 'he said"Hello"'

# %%
recipe = '''
afws
vdsag
sdg
swgedwedf
vads
'''
recipe
# Out:
# '\nafws\nvdsag\nsdg\nswgedwedf\nvads\n'

# %%
print(recipe)
# Out:
# afws
# vdsag
# sdg
# swgedwedf
# vads

# %%
recipe = "Veg biryani with saffron, cardamom, and cloves, garnished with fried onions and cilantro"

# %%
spice = "cardamom"
spice in recipe
# Out:
# True

# %%
"milk" in recipe
# Out:
# False

# %%
recipe.find(spice)
# Out:
# 26

# %%
s = "patient was charfged 100rs for test"
s
# Out:
# 'patient was charfged 100rs for test'

# %%
dir(s)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
s= s.replace("100rs", "1000rs")     #important to store back in same string becz strings are immutable

# %%
s
# Out:
# 'patient was charfged 1000rs for test'

# %%
s.upper()
# Out:
# 'PATIENT WAS CHARFGED 1000RS FOR TEST'

# %%
s
# Out:
# 'patient was charfged 1000rs for test'

# %%
'410'.isdigit()
# Out:
# True

# %%
text = "y age is: "               #imp
age=22
text+str(age)
# Out:
# 'y age is: 22'

# %%
s="hey\tbro"
s
# Out:
# 'hey\tbro'

# %%
print(s)
# Out:
# hey	bro

# %%
tickers = "AAPL|NVDA|RIL|GOGL"
tickers.split("|")
# Out:
# ['AAPL', 'NVDA', 'RIL', 'GOGL']

# %%
tickers = "AAPL|NVDA|RIL|GOGL"
tickers.split("|", maxsplit=2)
# Out:
# ['AAPL', 'NVDA', 'RIL|GOGL']

# %%
day= "   Hello my name    Rushi"
day
# Out:
# '   Hello my name    Rushi'

# %%
day.strip()
# Out:
# 'Hello my name    Rushi'

# %%
file_name="report.pdf"

file_name.endswith(".pdf")
# Out:
# True
